# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import seaborn as sns
from sklearn.feature_selection import mutual_info_regression as mir
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-5fc2a9b84822> in <module>
#       7
#       8 # import jtplot module in notebook
# ----> 9 from jupyterthemes import jtplot
#      10
#      11 # choose which theme to inherit plotting style from
#
# ModuleNotFoundError: No module named 'jupyterthemes'

# %% [markdown]
# ## Importing Data

# %%
colnames = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]
df = pd.read_csv("pima-indians-diabetes.csv", names=colnames)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = df.iloc[:,:-1]
y = df["Outcome"]

# %%
mir(X, y)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# array([0.02742288, 0.12251087, 0.        , 0.00908863, 0.05537071,
#        0.07706533, 0.00782765, 0.07775403])

# %%
y1 = df[df['Outcome'] == 1]
y0 = df[df['Outcome'] == 0]

# %%
for i in range(0,8): 
    sns.distplot(y1.iloc[:,i])
    plt.show()
