# %% [markdown]
# # TP Python : Pre-processing & Pandas
#
#
# ##  Un peu de pre-processing avec la team Star Wars
#
# Importer les 10 premiers personages de star wars depuis l'api du site [swapi](https://swapi.co/) et les ranger dans un dataframe de laçon suivante :
# <img src="./StarWarsResult.png">

# %%
import requests
import pandas as pd

# %%
r = requests.get('https://swapi.co/api/people/1')

# %%
data = r.json()

# %%
df = pd.DataFrame(columns=data.keys())
columns = list(df)

# %%
df
# Out:
# Empty DataFrame
# Columns: [name, height, mass, hair_color, skin_color, eye_color, birth_year, gender, homeworld, films, species, vehicles, starships, created, edited, url]
# Index: []

# %%
r = requests.get('https://swapi.co/api/people/1')
data = r.json()
data
# Out:
# {'name': 'Luke Skywalker',
#  'height': '172',
#  'mass': '77',
#  'hair_color': 'blond',
#  'skin_color': 'fair',
#  'eye_color': 'blue',
#  'birth_year': '19BBY',
#  'gender': 'male',
#  'homeworld': 'https://swapi.co/api/planets/1/',
#  'films': ['https://swapi.co/api/films/2/',
#   'https://swapi.co/api/films/6/',
#   'https://swapi.co/api/films/3/',
#   'https://swapi.co/api/films/1/',
#   'https://swapi.co/api/films/7/'],
#  'species': ['https://swapi.co/api/species/1/'],
#  'vehicles': ['https://swapi.co/api/vehicles/14/',
#   'https://swapi.co/api/vehicles/30/'],
#  'starships': ['https://swapi.co/api/starships/12/',
#   'https://swapi.co/api/starships/22/'],
#  'created': '2014-12-09T13:50:51.644000Z',
#  'edited': '2014-12-20T21:17:56.891000Z',
#  'url': 'https://swapi.co/api/people/1/'}

# %%
type(data["films"])
# Out:
# list

# %%
for x in range(1, 11):
    r = requests.get('https://swapi.co/api/people/' + str(x))
    data = r.json()
    for key in columns:
        df.loc[x, key] = str(data[key]).strip('[]')
df
# Out:
#                   name height mass     hair_color   skin_color  eye_color  \
# 1       Luke Skywalker    172   77          blond         fair       blue
# 2                C-3PO    167   75            n/a         gold     yellow
# 3                R2-D2     96   32            n/a  white, blue        red
# 4          Darth Vader    202  136           none        white     yellow
# 5          Leia Organa    150   49          brown        light      brown
# 6            Owen Lars    178  120    brown, grey        light       blue
# 7   Beru Whitesun lars    165   75          brown        light       blue
# 8                R5-D4     97   32            n/a   white, red        red
# 9    Biggs Darklighter    183   84          black        light      brown
# 10      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#    birth_year  gender                         homeworld  \
# 1       19BBY    male   https://swapi.co/api/planets/1/
# 2      112BBY     n/a   https://swapi.co/api/planets/1/
# 3       33BBY     n/a   https://swapi.co/api/planets/8/
# 4     41.9BBY    male   https://swapi.co/api/planets/1/
# 5       19BBY  female   https://swapi.co/api/planets/2/
# 6       52BBY    male   https://swapi.co/api/planets/1/
# 7       47BBY  female   https://swapi.co/api/planets/1/
# 8     unknown     n/a   https://swapi.co/api/planets/1/
# 9       24BBY    male   https://swapi.co/api/planets/1/
# 10      57BBY    male  https://swapi.co/api/planets/20/
#
#                                                 films  \
# 1   'https://swapi.co/api/films/2/', 'https://swap...
# 2   'https://swapi.co/api/films/2/', 'https://swap...
# 3   'https://swapi.co/api/films/2/', 'https://swap...
# 4   'https://swapi.co/api/films/2/', 'https://swap...
# 5   'https://swapi.co/api/films/2/', 'https://swap...
# 6   'https://swapi.co/api/films/5/', 'https://swap...
# 7   'https://swapi.co/api/films/5/', 'https://swap...
# 8                     'https://swapi.co/api/films/1/'
# 9                     'https://swapi.co/api/films/1/'
# 10  'https://swapi.co/api/films/2/', 'https://swap...
#
#                               species  \
# 1   'https://swapi.co/api/species/1/'
# 2   'https://swapi.co/api/species/2/'
# 3   'https://swapi.co/api/species/2/'
# 4   'https://swapi.co/api/species/1/'
# 5   'https://swapi.co/api/species/1/'
# 6   'https://swapi.co/api/species/1/'
# 7   'https://swapi.co/api/species/1/'
# 8   'https://swapi.co/api/species/2/'
# 9   'https://swapi.co/api/species/1/'
# 10  'https://swapi.co/api/species/1/'
#
#                                              vehicles  \
# 1   'https://swapi.co/api/vehicles/14/', 'https://...
# 2
# 3
# 4
# 5                 'https://swapi.co/api/vehicles/30/'
# 6
# 7
# 8
# 9
# 10                'https://swapi.co/api/vehicles/38/'
#
#                                             starships  \
# 1   'https://swapi.co/api/starships/12/', 'https:/...
# 2
# 3
# 4                'https://swapi.co/api/starships/13/'
# 5
# 6
# 7
# 8
# 9                'https://swapi.co/api/starships/12/'
# 10  'https://swapi.co/api/starships/48/', 'https:/...
#
#                         created                       edited  \
# 1   2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 2   2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 3   2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 4   2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 5   2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 6   2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 7   2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 8   2014-12-10T15:57:50.959000Z  2014-12-20T21:17:50.321000Z
# 9   2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 10  2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
#
#                                 url
# 1    https://swapi.co/api/people/1/
# 2    https://swapi.co/api/people/2/
# 3    https://swapi.co/api/people/3/
# 4    https://swapi.co/api/people/4/
# 5    https://swapi.co/api/people/5/
# 6    https://swapi.co/api/people/6/
# 7    https://swapi.co/api/people/7/
# 8    https://swapi.co/api/people/8/
# 9    https://swapi.co/api/people/9/
# 10  https://swapi.co/api/people/10/

# %% [markdown]
# for x in range(1,11):
#     r = requests.get('https://swapi.co/api/people/'+str(x))
#     data = r.json()
#     df = pd.DataFrame({ key:pd.Series(value) for key, value in data.items() })
