# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
dic = {'id:': [1,2,3,4,5]}

# %%
dic
# Out:
# {'id:': [1, 2, 3, 4, 5]}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#    id:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
df[:2]
# Out:
#    id:
# 0    1
# 1    2

# %%
df.shape
# Out:
# (5, 1)

# %%
df = pd.read_csv('Data/chipotle.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
type(df.quantity)
# Out:
# pandas.core.series.Series

# %%
for x in df:
    print(x)
# Out:
# Unnamed: 0
# order_id
# quantity
# item_name
# choice_description
# item_price

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       0.000000     1.000000     1.000000
# 25%    1155.250000   477.250000     1.000000
# 50%    2310.500000   926.000000     1.000000
# 75%    3465.750000  1393.000000     1.000000
# max    4621.000000  1834.000000    15.000000

# %%
new_df = df[df['quantity']>1]

# %%
new_df
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 4              4         2         2                           Chicken Bowl
# 18            18         9         2                            Canned Soda
# 51            51        23         2                            Canned Soda
# 135          135        60         2                     Chicken Salad Bowl
# 148          148        67         2                          Steak Burrito
# 150          150        68         2                        Chicken Burrito
# 154          154        70         2                           Chicken Bowl
# 162          162        73         2                            Canned Soda
# 171          171        76         2                            Canned Soda
# 213          213        94         2                     Chicken Salad Bowl
# 217          217        96         2                   Chicken Crispy Tacos
# ...
